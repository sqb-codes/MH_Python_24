# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("headbrain.csv")

# %%
df.shape
# Out:
# (237, 4)

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = df['Head Size(cm^3)'].values
y = df['Brain Weight(grams)'].values

# %%
X = np.reshape(X, (-1, 1))
y = np.reshape(y, (-1, 1))

minmax = MinMaxScaler()
X_scale = minmax.fit_transform(X)

# %%
y_scale = minmax.fit_transform(y)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_scale, y_scale)
plt.xlabel("Head Size")
plt.ylabel("Brain Weight")
plt.show()

# %%
regression = LinearRegression()
regression.fit(X_scale, y_scale)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_scale)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_scale, y_scale)
plt.plot(X_scale, y_pred, 'r')
plt.xlabel("Head Size")
plt.ylabel("Brain Weight")
plt.show()

# %%
mean_squared_error(y_scale, y_pred)
# Out:
# 0.011248667880627875
